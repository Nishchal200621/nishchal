# %%
from sympy import *1)
print(y)
# Out:
#   Cell In[47], line 1
#     from sympy import *1)
#                         ^
# SyntaxError: unmatched ')'

# %%
from pylab import *
theta=linspace(0,2*pi,1000)
r=2*abs(cos(2*theta))
polar(theta,r,'r')
show()
